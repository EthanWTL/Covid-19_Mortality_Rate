# %%
import numpy as np
import random
import os
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
import keras
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Activation, Flatten, Dense, Dropout, SimpleRNN
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import backend as K
from sklearn.metrics import confusion_matrix, classification_report
# Out:
# C:\Users\Ethan\AppData\Roaming\Python\Python39\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#binarize the labels
lb = LabelBinarizer()

import pandas as pd

data_files = ['cle_train.csv','cle_test.csv','hun_train.csv','hun_test.csv','swi_train.csv','swi_test.csv','vir_train.csv','vir_test.csv']

datasets = {}

for file in data_files:
    data = pd.read_csv('../TrainTestData/' + file)
    
    X = data.iloc[:, :-1]
    Y = data.iloc[:, -1]
    
    Y_binary = Y.apply(lambda x: 1 if x > 0 else 0)
    
    # Extract the name from the file path
    name = file.split('.')[0]
    
    # Store the dataset components in a dictionary
    datasets[name] = {'X': X, 'Y': Y, 'Y_binary': Y_binary}

# Unpack the dictionary values in a loop
variables = ['cle', 'hun', 'swi', 'vir']
train_test = ['train', 'test']

for var in variables:
    for tt in train_test:
        X, Y, Y_binary = datasets[f'{var}_{tt}'].values()
        globals()[f'{var}_X_{tt}'] = X
        globals()[f'{var}_Y_{tt}'] = Y
        globals()[f'{var}_Y_{tt}_binary'] = Y_binary

# %% [markdown]
# # creating train test

# %%
X_test = pd.concat([cle_X_test,hun_X_test,swi_X_test,vir_X_test])
y_test = pd.concat([cle_Y_test_binary,hun_Y_test_binary,swi_Y_test_binary,vir_Y_test_binary])

X_train = pd.concat([cle_X_train,hun_X_train,swi_X_train,vir_X_train])
y_train = pd.concat([cle_Y_train_binary,hun_Y_train_binary,swi_Y_train_binary,vir_Y_train_binary])

# %%
def create_clients():
    cle_zip = list(zip(cle_X_train.values,cle_Y_train_binary))
    hun_zip = list(zip(hun_X_train.values,hun_Y_train_binary))
    vir_zip = list(zip(vir_X_train.values,vir_Y_train_binary))
    swi_zip = list(zip(swi_X_train.values,swi_Y_train_binary))
    
    shards = [cle_zip, hun_zip, vir_zip,swi_zip]
    client_names = ["client_1","client_2","client_3","client_4"]
    dic = {client_names[i] : shards[i] for i in range(len(client_names))}
    return dic


def batch_data(data_shard, bs=32):
    '''Takes in a clients data shard and create a tfds object off it
    args:
        shard: a data, label constituting a client's data shard
        bs:batch size
    return:
        tfds object'''
    #seperate shard into data and labels lists
    data, label = zip(*data_shard)
    dataset = tf.data.Dataset.from_tensor_slices((list(data), list(label)))
    return dataset.shuffle(len(label)).batch(bs)


class DNN:
    @staticmethod
    def build():
        model = Sequential()
        model.add(Dense(64, input_shape=(35,), activation='relu'))
        model.add(Dense(192, activation='relu'))
        model.add(Dense(2, activation='sigmoid'))

        model.compile(loss='sparse_categorical_crossentropy', 
                      optimizer=keras.optimizers.Adam(learning_rate=0.001), 
                      metrics=['accuracy'])
        return model
    

def weight_scalling_factor(clients_trn_data, client_name):
    client_names = list(clients_trn_data.keys())
    #get the bs
    bs = list(clients_trn_data[client_name])[0][0].shape[0]
    #first calculate the total training data points across clinets
    global_count = sum([tf.data.experimental.cardinality(clients_trn_data[client_name]).numpy() for client_name in client_names])*bs
    # get the total number of data points held by a client
    local_count = tf.data.experimental.cardinality(clients_trn_data[client_name]).numpy()*bs
    return local_count/global_count


def scale_model_weights(weight, scalar):
    '''function for scaling a models weights'''
    weight_final = []
    steps = len(weight)
    for i in range(steps):
        weight_final.append(scalar * weight[i])
    return weight_final


def sum_scaled_weights(scaled_weight_list):
    '''Return the sum of the listed scaled weights. The is equivalent to scaled avg of the weights'''
    avg_grad = list()
    #get the average grad accross all client gradients
    for grad_list_tuple in zip(*scaled_weight_list):
        layer_mean = tf.math.reduce_sum(grad_list_tuple, axis=0)
        avg_grad.append(layer_mean)
        
    return avg_grad


def test_model(X_test, Y_test,  model, comm_round):
    cce = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
    logits = model.predict(X_test)
    length = len(y_test)
    Y_test = tf.reshape(Y_test,(length,1))
    loss = cce(Y_test, logits)
    acc = accuracy_score(tf.argmax(logits, axis=1), Y_test)
    cm_cle = confusion_matrix(tf.argmax(logits, axis=1), Y_test)
    recall = cm_cle[1][1]/(cm_cle[1][1]+cm_cle[0][1])
    precision = cm_cle[1][1]/(cm_cle[1][1]+cm_cle[1][0])
    print('comm_round: {} | global_acc: {:.3%} | global_loss: {} | recall_1: {:.4%} | precision_1: {:.4%}'
          .format(comm_round, acc, loss,recall,precision))
    return acc, loss

# %%
# create clients
clients = create_clients()

#process and batch the training data for each client
clients_batched = dict()
for (client_name, data) in clients.items():
    clients_batched[client_name] = batch_data(data)
    
#process and batch the test set  
test_batched = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(len(y_test))

comms_round = 100

#initialize global model
smlp_global = DNN()
global_model = smlp_global.build()

losslist = []
#commence global training loop
for comm_round in range(comms_round):
            
    # get the global model's weights - will serve as the initial weights for all local models
    global_weights = global_model.get_weights()
    
    #initial list to collect local model weights after scalling
    scaled_local_weight_list = list()

    #randomize client data - using keys
    client_names= list(clients_batched.keys())
    random.shuffle(client_names)
    
    #loop through each client and create new local model
    for client in client_names:
        smlp_local = DNN()
        local_model = smlp_local.build()
        local_model.compile(loss='sparse_categorical_crossentropy', 
                      optimizer=keras.optimizers.Adam(learning_rate=0.001), 
                      metrics=['accuracy'])
        
        #set local model weight to the weight of the global model
        local_model.set_weights(global_weights)
        
        #fit local model with client's data
        with tf.device('/device:GPU:0'):
            local_model.fit(clients_batched[client], epochs=1, verbose=0)
        
        #scale the model weights and add to list
        scaling_factor = weight_scalling_factor(clients_batched, client)
        scaled_weights = scale_model_weights(local_model.get_weights(), scaling_factor)
        scaled_local_weight_list.append(scaled_weights)
        
        #clear session to free memory after each communication round
        K.clear_session()
        
    #to get the average over all the local model, we simply take the sum of the scaled weights
    average_weights = sum_scaled_weights(scaled_local_weight_list)
    
    #update global model 
    global_model.set_weights(average_weights)

    #test global model and print out metrics after each communications round
    for(X_test, Y_test) in test_batched:
        global_acc, global_loss = test_model(X_test, Y_test, global_model, comm_round)
        losslist.append(global_loss)

    global_model.save('../Models/FL_DNN/train/FL_DNN_epoch'+str(comm_round)+'.h5')
# Out:
# 1773/1773 [==============================] - 2s 955us/step
# comm_round: 0 | global_acc: 76.100% | global_loss: 0.6062946915626526 | recall_1: 59.4459% | precision_1: 75.1558%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 1 | global_acc: 76.220% | global_loss: 0.6042347550392151 | recall_1: 55.1303% | precision_1: 78.5737%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 2 | global_acc: 76.373% | global_loss: 0.601868748664856 | recall_1: 57.2082% | precision_1: 77.3781%
# 1773/1773 [==============================] - 2s 981us/step
# comm_round: 3 | global_acc: 76.345% | global_loss: 0.6021053791046143 | recall_1: 56.1293% | precision_1: 78.1238%
# 1773/1773 [==============================] - 2s 981us/step
# comm_round: 4 | global_acc: 76.355% | global_loss: 0.5989999175071716 | recall_1: 56.8752% | precision_1: 77.5799%
# 1773/1773 [==============================] - 2s 996us/step
# comm_round: 5 | global_acc: 76.340% | global_loss: 0.5977829098701477 | recall_1: 53.8028% | precision_1: 80.0555%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 6 | global_acc: 76.389% | global_loss: 0.5999826788902283 | recall_1: 55.0104% | precision_1: 79.1542%
# 1773/1773 [==============================] - 2s 962us/step
# comm_round: 7 | global_acc: 76.438% | global_loss: 0.6012105345726013 | recall_1: 58.6512% | precision_1: 76.5132%
# 1773/1773 [==============================] - 2s 992us/step
# comm_round: 8 | global_acc: 76.412% | global_loss: 0.6016877889633179 | recall_1: 58.5757% | precision_1: 76.4989%
# 1773/1773 [==============================] - 2s 997us/step
# comm_round: 9 | global_acc: 76.435% | global_loss: 0.601832389831543 | recall_1: 57.9852% | precision_1: 76.9729%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 10 | global_acc: 76.401% | global_loss: 0.599931538105011 | recall_1: 56.8574% | precision_1: 77.7157%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 11 | global_acc: 76.401% | global_loss: 0.6013495922088623 | recall_1: 56.3557% | precision_1: 78.1012%
# 1773/1773 [==============================] - 2s 996us/step
# comm_round: 12 | global_acc: 76.421% | global_loss: 0.6020886301994324 | recall_1: 57.5589% | precision_1: 77.2448%
# 1773/1773 [==============================] - 2s 998us/step
# comm_round: 13 | global_acc: 76.387% | global_loss: 0.6029906272888184 | recall_1: 57.2259% | precision_1: 77.4021%
# 1773/1773 [==============================] - 2s 980us/step
# comm_round: 14 | global_acc: 76.421% | global_loss: 0.601521372795105 | recall_1: 57.5545% | precision_1: 77.2481%
# 1773/1773 [==============================] - 2s 995us/step
# comm_round: 15 | global_acc: 76.387% | global_loss: 0.5983718037605286 | recall_1: 58.4824% | precision_1: 76.5013%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 16 | global_acc: 76.414% | global_loss: 0.5983989834785461 | recall_1: 56.3957% | precision_1: 78.1037%
# 1773/1773 [==============================] - 2s 994us/step
# comm_round: 17 | global_acc: 76.468% | global_loss: 0.5976651310920715 | recall_1: 58.4380% | precision_1: 76.7374%
# 1773/1773 [==============================] - 2s 900us/step
# comm_round: 18 | global_acc: 76.421% | global_loss: 0.6007989048957825 | recall_1: 58.4913% | precision_1: 76.5797%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 19 | global_acc: 76.431% | global_loss: 0.6020181179046631 | recall_1: 59.8189% | precision_1: 75.7123%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 20 | global_acc: 76.451% | global_loss: 0.6043740510940552 | recall_1: 58.1983% | precision_1: 76.8617%
# 1773/1773 [==============================] - 2s 984us/step
# comm_round: 21 | global_acc: 76.407% | global_loss: 0.6001110672950745 | recall_1: 57.4080% | precision_1: 77.3187%
# 1773/1773 [==============================] - 2s 938us/step
# comm_round: 22 | global_acc: 76.444% | global_loss: 0.5995647311210632 | recall_1: 58.3315% | precision_1: 76.7496%
# 1773/1773 [==============================] - 2s 995us/step
# comm_round: 23 | global_acc: 76.421% | global_loss: 0.6010430455207825 | recall_1: 55.9739% | precision_1: 78.4554%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 24 | global_acc: 76.327% | global_loss: 0.6010280847549438 | recall_1: 57.8831% | precision_1: 76.7695%
# 1773/1773 [==============================] - 2s 990us/step
# comm_round: 25 | global_acc: 76.466% | global_loss: 0.5986180901527405 | recall_1: 58.5313% | precision_1: 76.6676%
# 1773/1773 [==============================] - 2s 938us/step
# comm_round: 26 | global_acc: 76.407% | global_loss: 0.5980988144874573 | recall_1: 57.6566% | precision_1: 77.1369%
# 1773/1773 [==============================] - 2s 991us/step
# comm_round: 27 | global_acc: 76.391% | global_loss: 0.6003985404968262 | recall_1: 59.6013% | precision_1: 75.7562%
# 1773/1773 [==============================] - 2s 990us/step
# comm_round: 28 | global_acc: 76.408% | global_loss: 0.5976385474205017 | recall_1: 57.8298% | precision_1: 77.0163%
# 1773/1773 [==============================] - 2s 925us/step
# comm_round: 29 | global_acc: 76.461% | global_loss: 0.6008829474449158 | recall_1: 57.7454% | precision_1: 77.2144%
# 1773/1773 [==============================] - 2s 984us/step
# comm_round: 30 | global_acc: 76.331% | global_loss: 0.6008046269416809 | recall_1: 60.8400% | precision_1: 74.8307%
# 1773/1773 [==============================] - 2s 997us/step
# comm_round: 31 | global_acc: 76.391% | global_loss: 0.5988938808441162 | recall_1: 57.0395% | precision_1: 77.5504%
# 1773/1773 [==============================] - 2s 995us/step
# comm_round: 32 | global_acc: 76.391% | global_loss: 0.5974902510643005 | recall_1: 56.6798% | precision_1: 77.8225%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 33 | global_acc: 76.385% | global_loss: 0.6001726984977722 | recall_1: 56.2714% | precision_1: 78.1237%
# 1773/1773 [==============================] - 2s 981us/step
# comm_round: 34 | global_acc: 76.396% | global_loss: 0.6012641191482544 | recall_1: 59.2772% | precision_1: 75.9832%
# 1773/1773 [==============================] - 2s 990us/step
# comm_round: 35 | global_acc: 76.338% | global_loss: 0.5963413715362549 | recall_1: 56.6621% | precision_1: 77.6939%
# 1773/1773 [==============================] - 2s 980us/step
# comm_round: 36 | global_acc: 76.401% | global_loss: 0.60062175989151 | recall_1: 55.9650% | precision_1: 78.4088%
# 1773/1773 [==============================] - 2s 930us/step
# comm_round: 37 | global_acc: 76.355% | global_loss: 0.5997881293296814 | recall_1: 57.8697% | precision_1: 76.8514%
# 1773/1773 [==============================] - 2s 984us/step
# comm_round: 38 | global_acc: 76.384% | global_loss: 0.6010059118270874 | recall_1: 58.4025% | precision_1: 76.5480%
# 1773/1773 [==============================] - 2s 977us/step
# comm_round: 39 | global_acc: 76.366% | global_loss: 0.6013818979263306 | recall_1: 56.2403% | precision_1: 78.0949%
# 1773/1773 [==============================] - 2s 991us/step
# comm_round: 40 | global_acc: 76.426% | global_loss: 0.601909339427948 | recall_1: 58.5091% | precision_1: 76.5807%
# 1773/1773 [==============================] - 2s 988us/step
# comm_round: 41 | global_acc: 76.377% | global_loss: 0.5985088348388672 | recall_1: 58.5757% | precision_1: 76.4103%
# 1773/1773 [==============================] - 2s 995us/step
# comm_round: 42 | global_acc: 76.417% | global_loss: 0.6000705361366272 | recall_1: 57.9230% | precision_1: 76.9721%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 43 | global_acc: 76.338% | global_loss: 0.5997764468193054 | recall_1: 56.4623% | precision_1: 77.8465%
# 1773/1773 [==============================] - 2s 997us/step
# comm_round: 44 | global_acc: 76.389% | global_loss: 0.6008594036102295 | recall_1: 58.8243% | precision_1: 76.2708%
# 1773/1773 [==============================] - 2s 925us/step
# comm_round: 45 | global_acc: 76.290% | global_loss: 0.599824845790863 | recall_1: 56.6710% | precision_1: 77.5597%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 46 | global_acc: 76.364% | global_loss: 0.6007823944091797 | recall_1: 59.0019% | precision_1: 76.0893%
# 1773/1773 [==============================] - 2s 962us/step
# comm_round: 47 | global_acc: 76.459% | global_loss: 0.6009507179260254 | recall_1: 58.6556% | precision_1: 76.5633%
# 1773/1773 [==============================] - 2s 970us/step
# comm_round: 48 | global_acc: 76.396% | global_loss: 0.599286675453186 | recall_1: 59.0596% | precision_1: 76.1289%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 49 | global_acc: 76.373% | global_loss: 0.5973886251449585 | recall_1: 58.7000% | precision_1: 76.3161%
# 1773/1773 [==============================] - 2s 939us/step
# comm_round: 50 | global_acc: 76.318% | global_loss: 0.5977978110313416 | recall_1: 57.8564% | precision_1: 76.7658%
# 1773/1773 [==============================] - 2s 970us/step
# comm_round: 51 | global_acc: 76.415% | global_loss: 0.6013373136520386 | recall_1: 59.8721% | precision_1: 75.6394%
# 1773/1773 [==============================] - 2s 977us/step
# comm_round: 52 | global_acc: 76.392% | global_loss: 0.597463071346283 | recall_1: 57.7587% | precision_1: 77.0265%
# 1773/1773 [==============================] - 2s 945us/step
# comm_round: 53 | global_acc: 76.350% | global_loss: 0.5990046858787537 | recall_1: 58.8776% | precision_1: 76.1383%
# 1773/1773 [==============================] - 2s 977us/step
# comm_round: 54 | global_acc: 76.355% | global_loss: 0.6007793545722961 | recall_1: 58.0695% | precision_1: 76.7097%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 55 | global_acc: 76.355% | global_loss: 0.599259078502655 | recall_1: 57.7010% | precision_1: 76.9723%
# 1773/1773 [==============================] - 2s 990us/step
# comm_round: 56 | global_acc: 76.345% | global_loss: 0.6008821725845337 | recall_1: 57.5811% | precision_1: 77.0314%
# 1773/1773 [==============================] - 2s 985us/step
# comm_round: 57 | global_acc: 76.301% | global_loss: 0.5983685851097107 | recall_1: 57.6877% | precision_1: 76.8407%
# 1773/1773 [==============================] - 2s 970us/step
# comm_round: 58 | global_acc: 76.332% | global_loss: 0.6023591160774231 | recall_1: 57.9186% | precision_1: 76.7579%
# 1773/1773 [==============================] - 2s 957us/step
# comm_round: 59 | global_acc: 76.304% | global_loss: 0.6001121401786804 | recall_1: 59.3527% | precision_1: 75.7094%
# 1773/1773 [==============================] - 2s 973us/step
# comm_round: 60 | global_acc: 76.301% | global_loss: 0.6002253293991089 | recall_1: 59.6457% | precision_1: 75.5101%
# 1773/1773 [==============================] - 2s 937us/step
# comm_round: 61 | global_acc: 76.329% | global_loss: 0.6003023982048035 | recall_1: 57.8253% | precision_1: 76.8151%
# 1773/1773 [==============================] - 2s 966us/step
# comm_round: 62 | global_acc: 76.320% | global_loss: 0.5955216288566589 | recall_1: 58.0207% | precision_1: 76.6542%
# 1773/1773 [==============================] - 2s 981us/step
# comm_round: 63 | global_acc: 76.269% | global_loss: 0.5996168851852417 | recall_1: 56.9773% | precision_1: 77.2746%
# 1773/1773 [==============================] - 2s 977us/step
# comm_round: 64 | global_acc: 76.336% | global_loss: 0.5968843102455139 | recall_1: 58.6467% | precision_1: 76.2600%
# 1773/1773 [==============================] - 2s 968us/step
# comm_round: 65 | global_acc: 76.287% | global_loss: 0.5998625159263611 | recall_1: 58.7622% | precision_1: 76.0588%
# 1773/1773 [==============================] - 2s 966us/step
# comm_round: 66 | global_acc: 76.251% | global_loss: 0.5995264053344727 | recall_1: 57.5767% | precision_1: 76.7928%
# 1773/1773 [==============================] - 2s 939us/step
# comm_round: 67 | global_acc: 76.318% | global_loss: 0.599424421787262 | recall_1: 58.5402% | precision_1: 76.2888%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 68 | global_acc: 76.271% | global_loss: 0.6001408696174622 | recall_1: 58.0118% | precision_1: 76.5347%
# 1773/1773 [==============================] - 2s 955us/step
# comm_round: 69 | global_acc: 76.315% | global_loss: 0.6000018119812012 | recall_1: 57.6655% | precision_1: 76.8930%
# 1773/1773 [==============================] - 2s 990us/step
# comm_round: 70 | global_acc: 76.228% | global_loss: 0.5974224209785461 | recall_1: 56.9240% | precision_1: 77.2070%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 71 | global_acc: 76.232% | global_loss: 0.5980634689331055 | recall_1: 57.4479% | precision_1: 76.8349%
# 1773/1773 [==============================] - 2s 981us/step
# comm_round: 72 | global_acc: 76.295% | global_loss: 0.6001582145690918 | recall_1: 57.7676% | precision_1: 76.7701%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 73 | global_acc: 76.232% | global_loss: 0.5971762537956238 | recall_1: 56.8619% | precision_1: 77.2623%
# 1773/1773 [==============================] - 2s 986us/step
# comm_round: 74 | global_acc: 76.236% | global_loss: 0.5995966792106628 | recall_1: 57.6788% | precision_1: 76.6793%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 75 | global_acc: 76.285% | global_loss: 0.5987358093261719 | recall_1: 59.3127% | precision_1: 75.6884%
# 1773/1773 [==============================] - 2s 964us/step
# comm_round: 76 | global_acc: 76.253% | global_loss: 0.5986825227737427 | recall_1: 58.4869% | precision_1: 76.1621%
# 1773/1773 [==============================] - 2s 990us/step
# comm_round: 77 | global_acc: 76.340% | global_loss: 0.5972102880477905 | recall_1: 58.6600% | precision_1: 76.2597%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 78 | global_acc: 76.273% | global_loss: 0.5980774760246277 | recall_1: 57.9186% | precision_1: 76.6046%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 79 | global_acc: 76.264% | global_loss: 0.5985228419303894 | recall_1: 57.8609% | precision_1: 76.6228%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 80 | global_acc: 76.250% | global_loss: 0.5969712138175964 | recall_1: 58.2871% | precision_1: 76.2901%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 81 | global_acc: 76.218% | global_loss: 0.597608745098114 | recall_1: 57.2437% | precision_1: 76.9456%
# 1773/1773 [==============================] - 2s 964us/step
# comm_round: 82 | global_acc: 76.250% | global_loss: 0.6017339825630188 | recall_1: 58.4336% | precision_1: 76.1896%
# 1773/1773 [==============================] - 2s 943us/step
# comm_round: 83 | global_acc: 76.135% | global_loss: 0.6024284958839417 | recall_1: 60.0675% | precision_1: 74.8492%
# 1773/1773 [==============================] - 2s 973us/step
# comm_round: 84 | global_acc: 76.190% | global_loss: 0.5985101461410522 | recall_1: 58.9131% | precision_1: 75.7190%
# 1773/1773 [==============================] - 2s 985us/step
# comm_round: 85 | global_acc: 76.266% | global_loss: 0.599959135055542 | recall_1: 58.5934% | precision_1: 76.1204%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 86 | global_acc: 76.228% | global_loss: 0.600677490234375 | recall_1: 58.4158% | precision_1: 76.1489%
# 1773/1773 [==============================] - 2s 973us/step
# comm_round: 87 | global_acc: 76.216% | global_loss: 0.5996906757354736 | recall_1: 56.0583% | precision_1: 77.8278%
# 1773/1773 [==============================] - 2s 966us/step
# comm_round: 88 | global_acc: 76.195% | global_loss: 0.5997284054756165 | recall_1: 58.3182% | precision_1: 76.1317%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 89 | global_acc: 76.176% | global_loss: 0.5971333980560303 | recall_1: 57.6477% | precision_1: 76.5476%
# 1773/1773 [==============================] - 2s 993us/step
# comm_round: 90 | global_acc: 76.262% | global_loss: 0.5971391201019287 | recall_1: 59.9698% | precision_1: 75.2102%
# 1773/1773 [==============================] - 2s 973us/step
# comm_round: 91 | global_acc: 76.285% | global_loss: 0.5980212092399597 | recall_1: 56.6354% | precision_1: 77.5724%
# 1773/1773 [==============================] - 2s 993us/step
# comm_round: 92 | global_acc: 76.248% | global_loss: 0.5986105799674988 | recall_1: 59.1395% | precision_1: 75.7119%
# 1773/1773 [==============================] - 2s 977us/step
# comm_round: 93 | global_acc: 76.220% | global_loss: 0.5988723635673523 | recall_1: 59.2994% | precision_1: 75.5387%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 94 | global_acc: 76.228% | global_loss: 0.5976687669754028 | recall_1: 58.1050% | precision_1: 76.3625%
# 1773/1773 [==============================] - 2s 988us/step
# comm_round: 95 | global_acc: 76.241% | global_loss: 0.6015323400497437 | recall_1: 58.9841% | precision_1: 75.7973%
# 1773/1773 [==============================] - 2s 967us/step
# comm_round: 96 | global_acc: 76.266% | global_loss: 0.6010911464691162 | recall_1: 58.8687% | precision_1: 75.9349%
# 1773/1773 [==============================] - 2s 1ms/step
# comm_round: 97 | global_acc: 76.213% | global_loss: 0.6006035804748535 | recall_1: 57.7898% | precision_1: 76.5422%
# 1773/1773 [==============================] - 2s 984us/step
# comm_round: 98 | global_acc: 76.216% | global_loss: 0.5992223024368286 | recall_1: 57.4613% | precision_1: 76.7843%
# 1773/1773 [==============================] - 2s 963us/step
# comm_round: 99 | global_acc: 76.186% | global_loss: 0.5966618657112122 | recall_1: 57.0395% | precision_1: 77.0111%

# %% [markdown]
# # Testing on each dataset on the best performanced model

# %%
global_model = tf.keras.models.load_model('../Models/FL_DNN/train/FL_DNN_epoch30.h5')

# %%
Y_predictions = np.argmax(global_model.predict(X_test),axis = 1)
cm = confusion_matrix(Y_predictions, Y_test)
print(cm)
print(classification_report(Y_test, Y_predictions, digits=4))
# Out:
# 1773/1773 [==============================] - 2s 1ms/step
# [[29604  8820]
#  [ 4609 13703]]
#               precision    recall  f1-score   support
#
#            0     0.7705    0.8653    0.8151     34213
#            1     0.7483    0.6084    0.6711     22523
#
#     accuracy                         0.7633     56736
#    macro avg     0.7594    0.7368    0.7431     56736
# weighted avg     0.7617    0.7633    0.7580     56736

# %%
Y_cle = np.argmax(global_model.predict(cle_X_test),axis = 1)
cm_cle = confusion_matrix(Y_cle, cle_Y_test_binary)
print(np.bincount(cle_Y_test_binary))
print(cm_cle)
recall = cm_cle[1][1]/np.bincount(cle_Y_test_binary)[1]
print('actual recall for class 1 is: ' + str(recall))
print(classification_report(Y_cle, cle_Y_test_binary, digits=4))
# Out:
# 444/444 [==============================] - 0s 1ms/step
# [8535 5649]
# [[7365 2214]
#  [1170 3435]]
# actual recall for class 1 is: 0.608072225172597
#               precision    recall  f1-score   support
#
#            0     0.8629    0.7689    0.8132      9579
#            1     0.6081    0.7459    0.6700      4605
#
#     accuracy                         0.7614     14184
#    macro avg     0.7355    0.7574    0.7416     14184
# weighted avg     0.7802    0.7614    0.7667     14184

# %%
Y_vir = np.argmax(global_model.predict(vir_X_test),axis = 1)
cm_vir = confusion_matrix(Y_vir, vir_Y_test_binary)
print(np.bincount(vir_Y_test_binary))
print(cm_vir)
recall = cm_vir[1][1]/np.bincount(vir_Y_test_binary)[1]
print('actual recall for class 1 is: ' + str(recall))
print(classification_report(Y_vir, vir_Y_test_binary, digits=4))
# Out:
# 444/444 [==============================] - 0s 1ms/step
# [8647 5537]
# [[7495 2165]
#  [1152 3372]]
# actual recall for class 1 is: 0.6089940400939137
#               precision    recall  f1-score   support
#
#            0     0.8668    0.7759    0.8188      9660
#            1     0.6090    0.7454    0.6703      4524
#
#     accuracy                         0.7661     14184
#    macro avg     0.7379    0.7606    0.7446     14184
# weighted avg     0.7846    0.7661    0.7714     14184

# %%
Y_hun = np.argmax(global_model.predict(hun_X_test),axis = 1)
cm_hun = confusion_matrix(Y_hun, hun_Y_test_binary)
print(np.bincount(hun_Y_test_binary))
print(cm_hun)
recall = cm_hun[1][1]/np.bincount(hun_Y_test_binary)[1]
print('actual recall for class 1 is: ' + str(recall))
print(classification_report(Y_hun, hun_Y_test_binary, digits=4))
# Out:
# 444/444 [==============================] - 0s 1ms/step
# [8541 5643]
# [[7419 2198]
#  [1122 3445]]
# actual recall for class 1 is: 0.6104908736487684
#               precision    recall  f1-score   support
#
#            0     0.8686    0.7714    0.8172      9617
#            1     0.6105    0.7543    0.6748      4567
#
#     accuracy                         0.7659     14184
#    macro avg     0.7396    0.7629    0.7460     14184
# weighted avg     0.7855    0.7659    0.7713     14184

# %%
Y_swi = np.argmax(global_model.predict(swi_X_test),axis = 1)
cm_swi = confusion_matrix(Y_swi, swi_Y_test_binary)
print(np.bincount(swi_Y_test_binary))
print(cm_swi)
recall = cm_swi[1][1]/np.bincount(swi_Y_test_binary)[1]
print('actual recall for class 1 is: ' + str(recall))
print(classification_report(Y_swi, swi_Y_test_binary, digits=4))
# Out:
# 444/444 [==============================] - 0s 1ms/step
# [8490 5694]
# [[7325 2243]
#  [1165 3451]]
# actual recall for class 1 is: 0.6060765718299965
#               precision    recall  f1-score   support
#
#            0     0.8628    0.7656    0.8113      9568
#            1     0.6061    0.7476    0.6694      4616
#
#     accuracy                         0.7597     14184
#    macro avg     0.7344    0.7566    0.7404     14184
# weighted avg     0.7792    0.7597    0.7651     14184
